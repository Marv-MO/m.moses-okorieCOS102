# %%
import tkinter as tk
from tkinter import messagebox
import random

class Employee:
    def __init__(self, name):
        self.name = name
        self.employees = [
            "Mary Evans", "Eyo Ishan", "Durojaiye Dare", "Adams Ali", "Andrew Ugwu", "Stella Makinde", "Jane Akibo", "Ago James", "Michell Taiwo", "Abraham Jones", "Nicole Anide", "Kosi Korso", "Adele Martins", "Emmanuel Ojo", "Ajayi Fatima"
        ]
        self.tasks = [
            "Loading", "Transporting", "Reviewing Orders", "Customer Service", "Delvering Items"
        ]

    def check_employee(self):
        return self.name in self.employees
        
    def take_attendance(self):
        return f"Attendance marked for {self.name}."

    def assign_task(self):
        task = random.choice(self.tasks)
        return f"Task assigned: {task}"

    def refuse_access(self):
        return "Access denied. You are not an employee."


class App:
    def __init__(self, root):
        self.root = root
        self.root.title("Employee Verification System")
        self.root.geometry("400x350")

        self.label = tk.Label(root, text="Enter your name:", font=("Arial", 10, "bold"))
        self.label.pack(pady=10)

        self.entry = tk.Entry(root, width=30)
        self.entry.pack(pady=10)

        self.button = tk.Button(root, text="Submit", command=self.verify_employee, bg="#4CAF50", fg="white")
        self.button.pack(pady=10)

        self.output = tk.Label(root, text="", wraplength=350, justify="center")
        self.output.pack(pady=20)

    def verify_employee(self):
        name = self.entry.get().strip()
        if not name:
            messageboxshowwarning("Input Error", "Please enter a name.")
            return
        employee = Employee(name)

        if emp.check_employee():
            attendance = emp.take_attendance()
            task = emp.assign_task()
            result = f"Welcome, {name}!\n{attendance}\n{task}"
            self.ouput.config(text=result, fg="green")
        else:
            result = emp.refuse_access()
            messagebox.showerror("Error", result)
        
if __name__ == "__main__":
    root = tk.Tk()
    app = App(root)
    root.mainloop()
