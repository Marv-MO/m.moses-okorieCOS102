# %% [markdown]
# ![IMG_20260311_194417.jpg](attachment:IMG_20260311_194417.jpg)

# %%
INPUT item prices COMPUTE subtotal PRINT subtoal PROCESS payment COMPUTE change PRINT change PRINT receipt UPDATE inventory

# %%
INPUT name1 INPUT name2 INPUT age1 INPUT age2 LET temp = age1 LET age2 = temp LET age1 = age2 PRINT age1 PRINT age2
