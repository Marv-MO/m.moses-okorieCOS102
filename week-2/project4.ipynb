# %%
import math

print("Izifin Technology\n")
years_of_experience = float(input("How long have you been in this business: "))
age = float(input("How old are you: "))
print("Years of Experience: ", years_of_experience)
print("Staff's Age: ", age)

if years_of_experience > 25 and age >= 55:
    ATR = 5600000
    print("Annual Tax Rate: ", ATR)

elif years_of_experience > 20 and age >= 45:
    ATR = 4480000
    print("Annual Tax Rate: ", ATR)

elif years_of_experience > 10 and age >= 35: 
    ATR = 1500000
    print("Annual Tax Rate: ", ATR)

else:
    ATR = 550000
    print("Annual Tax Rate: ", ATR)
# Out:
# Izifin Technology
# Years of Experience:  25.0
# Staff's Age:  25.0
# Annual Tax Rate:  550000
