# %% [markdown]
# ![WhatsApp Image 2026-03-14 at 13.25.34.jpeg](<attachment:WhatsApp Image 2026-03-14 at 13.25.34.jpeg>)

# %%
from tabulate import tabulate

Name = ["Evelyn", "Jessica", "Somto", "Edith", "Lisa", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
Age = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
Height = [5.5, 6, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
Scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

table = zip(Name, Age, Height, Scores)
print(tabulate(table, headers=["Name", "Age", "Height", "Scores"], tablefmt="grid"))
# Out:
# +---------+-------+----------+----------+
# | Name    |   Age |   Height |   Scores |
# +=========+=======+==========+==========+
# | Evelyn  |    17 |      5.5 |       80 |
# +---------+-------+----------+----------+
# | Jessica |    16 |      6   |       85 |
# +---------+-------+----------+----------+
# | Somto   |    17 |      5.4 |       70 |
# +---------+-------+----------+----------+
# | Edith   |    18 |      5.9 |       60 |
# +---------+-------+----------+----------+
# | Lisa    |    16 |      5.6 |       76 |
# +---------+-------+----------+----------+
# | Madonna |    18 |      5.5 |       66 |
# +---------+-------+----------+----------+
# | Waje    |    17 |      6.1 |       87 |
# +---------+-------+----------+----------+
# | Tola    |    20 |      6   |       95 |
# +---------+-------+----------+----------+
# | Aisha   |    19 |      5.7 |       50 |
# +---------+-------+----------+----------+
# | Latifa  |    17 |      5.5 |       49 |
# ...

# %%
from tabulate import tabulate

Name = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
Age = [19, 16, 18, 17, 20, 19, 16, 18, 17, 18]
Height = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
Scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

table = zip(Name, Age, Height, Scores)
print(tabulate(table, headers=["Name", "Age", "Height", "Scores"], tablefmt="grid"))
# Out:
# +---------+-------+----------+----------+
# | Name    |   Age |   Height |   Scores |
# +=========+=======+==========+==========+
# | Chinedu |    19 |      5.7 |       74 |
# +---------+-------+----------+----------+
# | Liam    |    16 |      5.9 |       87 |
# +---------+-------+----------+----------+
# | Wale    |    18 |      5.8 |       75 |
# +---------+-------+----------+----------+
# | Gbenga  |    17 |      6.1 |       68 |
# +---------+-------+----------+----------+
# | Abiola  |    20 |      5.9 |       66 |
# +---------+-------+----------+----------+
# | Kola    |    19 |      5.5 |       78 |
# +---------+-------+----------+----------+
# | Kunle   |    16 |      6.1 |       87 |
# +---------+-------+----------+----------+
# | George  |    18 |      5.4 |       98 |
# +---------+-------+----------+----------+
# | Thomas  |    17 |      5.8 |       54 |
# +---------+-------+----------+----------+
# | Wesley  |    18 |      5.7 |       60 |
# ...
